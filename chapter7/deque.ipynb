# %%
#Deque

# %%
import collections

# %%
type(collections)
# Out:
# module

# %%
from collections import deque

# %%
type(deque)
# Out:
# type

# %%
dq1 = deque()

# %%
dq1
# Out:
# deque([])

# %%
type(dq1)
# Out:
# collections.deque

# %%
print(dq1)
# Out:
# deque([])

# %%
pprint
# Out:
# Pretty printing has been turned OFF

# %%
dir(dq1)
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__copy__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'appendleft', 'clear', 'copy', 'count', 'extend', 'extendleft', 'index', 'insert', 'maxlen', 'pop', 'popleft', 'remove', 'reverse', 'rotate']

# %%
'append', , 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 
'reverse'

# %%
'appendleft', 'extendleft', 'maxlen', 'rotate'

# %%
dq1.append(100)

# %%
dq1
# Out:
# deque([100])

# %%
dq1.appendleft(111)

# %%
dq1
# Out:
# deque([111, 100])

# %%
dq1.append(200)

# %%
dq1
# Out:
# deque([111, 100, 200])

# %%
dq1.extend([300,400])

# %%
dq1
# Out:
# deque([111, 100, 200, 300, 400])

# %%
dq1.extendleft([222,333])

# %%
dq1
# Out:
# deque([333, 222, 111, 100, 200, 300, 400])

# %%
dq1.maxlen

# %%
len(dq1)
# Out:
# 7

# %%
dq1.pop()
# Out:
# 400

# %%
dq1
# Out:
# deque([333, 222, 111, 100, 200, 300])

# %%
dq1.popleft()
# Out:
# 333

# %%
dq1
# Out:
# deque([222, 111, 100, 200, 300])

# %%
dq1.rotate()

# %%
dq1
# Out:
# deque([300, 222, 111, 100, 200])

# %%
dq1.rotate()

# %%
dq1
# Out:
# deque([200, 300, 222, 111, 100])

# %%
DQ2 = deque(maxlen=5)

# %%
DQ2.maxlen
# Out:
# 5

# %%
DQ2
# Out:
# deque([], maxlen=5)

# %%
DQ2.append(100)

# %%
DQ2.append(200)

# %%
DQ2.append(300)

# %%
DQ2.append(400)

# %%
DQ2
# Out:
# deque([100, 200, 300, 400], maxlen=5)

# %%
DQ2.append(500)

# %%
DQ2
# Out:
# deque([100, 200, 300, 400, 500], maxlen=5)

# %%
DQ2.append(600)

# %%
DQ2
# Out:
# deque([200, 300, 400, 500, 600], maxlen=5)

# %%
DQ2.appendleft(111)

# %%
DQ2
# Out:
# deque([111, 200, 300, 400, 500], maxlen=5)
