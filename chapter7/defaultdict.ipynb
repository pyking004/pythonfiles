# %%
#default dict is dictionary
from collections import defaultdict

# %%
type(defaultdict)
# Out:
# type

# %%
students = {101:'ravi',102:'ramu',103:'hari',104:'ravi',105:'ramu',106:'ravi'}

# %% [raw]
# d1 = {'ravi':[101,104,106],'ramu':[102,105],'hari':[103]}

# %%
students
# Out:
# {101: 'ravi', 102: 'ramu', 103: 'hari', 104: 'ravi', 105: 'ramu', 106: 'ravi'}

# %%
studentInfo = [['ravi',101],['ramu',102],['ravi',103],['ramu',104],['ravi',105]]

# %%
studentInfo
# Out:
# [['ravi', 101], ['ramu', 102], ['ravi', 103], ['ramu', 104], ['ravi', 105]]

# %%
for i in studentInfo:
    print(i)
# Out:
# ['ravi', 101]
# ['ramu', 102]
# ['ravi', 103]
# ['ramu', 104]
# ['ravi', 105]

# %%
for i in studentInfo:
    print(i[0])
# Out:
# ravi
# ramu
# ravi
# ramu
# ravi

# %%
for i in studentInfo:
    print(i[1])
# Out:
# 101
# 102
# 103
# 104
# 105

# %%
for i in studentInfo:
    print(i[0],i[1])
# Out:
# ravi 101
# ramu 102
# ravi 103
# ramu 104
# ravi 105

# %% [raw]
# d1 = {'ravi':[101,104,106],'ramu':[102,105],'hari':[103]}

# %%
DD1 = defaultdict(list)

# %%
DD1
# Out:
# defaultdict(list, {})

# %%
DD1.default_factory
# Out:
# list

# %%
DD1.default_factory()
# Out:
# []

# %%
DD1['ravi'].append(101)

# %%
DD1
# Out:
# defaultdict(list, {'ravi': [101]})

# %%
DD1['ravi'].append(102)

# %%
DD1
# Out:
# defaultdict(list, {'ravi': [101, 102]})

# %%
DD1['hari'].append(103)

# %%
DD1
# Out:
# defaultdict(list, {'ravi': [101, 102], 'hari': [103]})

# %%
DD1['giri'].append(104)

# %%
DD1
# Out:
# defaultdict(list, {'ravi': [101, 102], 'hari': [103], 'giri': [104]})

# %%
DD1['hari'].append(105)

# %%
DD1
# Out:
# defaultdict(list, {'ravi': [101, 102], 'hari': [103, 105], 'giri': [104]})

# %%
studentInfo = [['ravi',101],['ramu',102],['ravi',103],['ramu',104],['ravi',105]]

# %%
DD2 = defaultdict(list)

# %%
DD2
# Out:
# defaultdict(list, {})

# %%
DD2.default_factory
# Out:
# list

# %%
DD2.default_factory()
# Out:
# []

# %%
for name,sid in studentInfo:
    print(name,sid)
# Out:
# ravi 101
# ramu 102
# ravi 103
# ramu 104
# ravi 105

# %%
for name,sid in studentInfo:
    DD2[name].append(sid)

# %%
DD2
# Out:
# defaultdict(list, {'ravi': [101, 103, 105], 'ramu': [102, 104]})

# %%
v1 = "mississippi"

# %%
for i in v1:
    print(i)
# Out:
# m
# i
# s
# s
# i
# s
# s
# i
# p
# p
# i

# %%
v1.count('i')
# Out:
# 4

# %%
DD3 = defaultdict(int)

# %%
DD3
# Out:
# defaultdict(int, {})

# %%
DD3.default_factory
# Out:
# int

# %%
DD3.default_factory()
# Out:
# 0

# %%
for i in v1:
    DD3[i] = DD3[i] + 1

# %%
DD3
# Out:
# defaultdict(int, {'m': 1, 'i': 4, 's': 4, 'p': 2})

# %%
DD4 = defaultdict(int)

# %%
name = input("Enter student Name = ")
DD4[name] = DD4[name]+1
print(DD4)
# Out:
# Enter student Name =  ravi
# defaultdict(<class 'int'>, {'ravi': 3, 'hari': 2, 'kumar': 2, 'gir': 2})
