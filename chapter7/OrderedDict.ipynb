# %%
from collections import OrderedDict

# %%
D1 = {4:400,2:200,1:100,6:600,5:500}

# %%
D1
# Out:
# {4: 400, 2: 200, 1: 100, 6: 600, 5: 500}

# %%
OD1 = OrderedDict(D1)

# %%
OD1
# Out:
# OrderedDict([(4, 400), (2, 200), (1, 100), (6, 600), (5, 500)])

# %%
OD1.move_to_end(4)

# %%
OD1
# Out:
# OrderedDict([(2, 200), (1, 100), (6, 600), (5, 500), (4, 400)])

# %%
OD1.move_to_end(5)

# %%
OD1
# Out:
# OrderedDict([(2, 200), (1, 100), (6, 600), (4, 400), (5, 500)])

# %%
OD1.move_to_end(6)

# %%
OD1
# Out:
# OrderedDict([(2, 200), (1, 100), (4, 400), (5, 500), (6, 600)])

# %%
OD1.move_to_end(1,last=False)

# %%
OD1
# Out:
# OrderedDict([(1, 100), (2, 200), (4, 400), (5, 500), (6, 600)])

# %%
D2 = dict(OD1)

# %%
D2
# Out:
# {1: 100, 2: 200, 4: 400, 5: 500, 6: 600}

# %%
for i in OD1.items():
    print(i)
# Out:
# (1, 100)
# (2, 200)
# (4, 400)
# (5, 500)
# (6, 600)
