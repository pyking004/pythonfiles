# %%
from collections import namedtuple

# %%
type(namedtuple)
# Out:
# function

# %%
StudentInfo = namedtuple('students','sid sname course fee')

# %%
type(StudentInfo)
# Out:
# type

# %%
class StudentInfo101:
    def __init__(self,sid,sname,course,fee):
        self.sid = sid
        self.sname = sname
        self.course = course
        self.fee = fee

# %%
std1 = StudentInfo101(5001,'ramu','java',15000)

# %%
std1.sid
# Out:
# 5001

# %%
student1 = StudentInfo(1001,'varma','java',15000)

# %%
student1.sid
# Out:
# 1001

# %%
student1.sname
# Out:
# 'varma'

# %%
student1.course
# Out:
# 'java'

# %%
student1.fee
# Out:
# 15000

# %%
student1.count('varma')
# Out:
# 1

# %%
student1.index("java")
# Out:
# 2

# %%
student2 = StudentInfo(1001,'varma','java',15000,'hyderabad')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 student2 = StudentInfo(1001,'varma','java',15000,'hyderabad')
#
# TypeError: students.__new__() takes 5 positional arguments but 6 were given

# %%
student2 = StudentInfo(1001,'varma','java')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 student2 = StudentInfo(1001,'varma','java')
#
# TypeError: students.__new__() missing 1 required positional argument: 'fee'
