# %%
import queue

# %%
type(queue)
# Out:
# module

# %%
#importing Queue class from queue.py file
from queue import Queue

# %%
type(Queue)
# Out:
# type

# %%
Q1 = Queue()

# %%
Q1.not_full
# Out:
# <Condition(<unlocked _thread.lock object at 0x0000025F52107CD0>, 0)>

# %%
bool(Q1.not_full)
# Out:
# True

# %%
Q1.put(100)

# %%
Q1.put(200)

# %%
Q1.put(300)

# %%
Q1.put(400)

# %%
print(Q1)

# %%
Q1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 Q1[0]
#
# TypeError: 'Queue' object is not subscriptable

# %%
Q1[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 Q1[:]
#
# TypeError: 'Queue' object is not subscriptable

# %%
len(Q1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 len(Q1)
#
# TypeError: object of type 'Queue' has no len()

# %%
for i in Q1:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 for i in Q1:
#       2     print(i)
#
# TypeError: 'Queue' object is not iterable

# %%
next(Q1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 next(Q1)
#
# TypeError: 'Queue' object is not an iterator

# %%
Q1.qsize()
# Out:
# 4

# %%
Q1.put(500)

# %%
Q1.qsize()
# Out:
# 5

# %%
pprint
# Out:
# Pretty printing has been turned OFF

# %%
dir(Q1)
# Out:
# ['__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_get', '_init', '_put', '_qsize', 'all_tasks_done', 'empty', 'full', 'get', 'get_nowait', 'is_shutdown', 'join', 'maxsize', 'mutex', 'not_empty', 'not_full', 'put', 'put_nowait', 'qsize', 'queue', 'shutdown', 'task_done', 'unfinished_tasks']

# %%
Q1.get()
# Out:
# 100

# %%
Q1.qsize()
# Out:
# 4

# %%
Q1.get()
# Out:
# 200

# %%
Q1.get()
# Out:
# 300

# %%
Q1.get()
# Out:
# 400

# %%
Q1.get()
# Out:
# 500

# %%
Q1.get()

# %%
from queue import Queue

# %%
Q2 = Queue()

# %%
Q2.put(10)
Q2.put(20)
Q2.put(30)
Q2.put(40)
Q2.put(50)

# %%
Q2.qsize()
# Out:
# 5

# %%
if Q2.not_full:
    print("Queue is not yet full")
# Out:
# Queue is not yet full

# %%
cnt = Q2.qsize()

# %%
for i in range(cnt):
    print(Q2.get())
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
Q3 = Queue()

# %%
Q3.empty()
# Out:
# True

# %%
Q3.full()
# Out:
# False

# %%
Q3.put(100)

# %%
Q3.empty()
# Out:
# False

# %%
Q3.full()
# Out:
# False

# %%
from queue import Queue

# %%
Q4 = Queue(maxsize=5)

# %%
Q4.put(100)

# %%
Q4.put(200)

# %%
Q4.put(300)

# %%
Q4.put(400)

# %%
Q4.put(500)

# %%
Q4.put_nowait(600)
# Out:
# ---------------------------------------------------------------------------
# Full                                      Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 Q4.put_nowait(600)
#
# File ~\anaconda3\Lib\queue.py:223, in Queue.put_nowait(self, item)
#     217 def put_nowait(self, item):
#     218     '''Put an item into the queue without blocking.
#     219
#     220     Only enqueue the item if a free slot is immediately available.
#     221     Otherwise raise the Full exception.
#     222     '''
# --> 223     return self.put(item, block=False)
#
# File ~\anaconda3\Lib\queue.py:156, in Queue.put(self, item, block, timeout)
#     154 if not block:
#     155     if self._qsize() >= self.maxsize:
# --> 156         raise Full
#     157 elif timeout is None:
#     158     while self._qsize() >= self.maxsize:
#
# Full:

# %%
print(Q4.get())
# Out:
# 100

# %%
print(Q4.get())
print(Q4.get())
print(Q4.get())
print(Q4.get())
# Out:
# 200
# 300
# 400
# 500

# %%
Q2.qsize()
# Out:
# 0

# %%
Q4.get_nowait()
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 Q4.get_nowait()
#
# File ~\anaconda3\Lib\queue.py:231, in Queue.get_nowait(self)
#     225 def get_nowait(self):
#     226     '''Remove and return an item from the queue without blocking.
#     227
#     228     Only get an item if one is immediately available. Otherwise
#     229     raise the Empty exception.
#     230     '''
# --> 231     return self.get(block=False)
#
# File ~\anaconda3\Lib\queue.py:196, in Queue.get(self, block, timeout)
#     194 if not block:
#     195     if not self._qsize():
# --> 196         raise Empty
#     197 elif timeout is None:
#     198     while not self._qsize():
#
# Empty:

# %%
Q5 = Queue(maxsize=5)

# %%
Q5.put(100)
Q5.put(200)

# %%
Q5.qsize()
# Out:
# 2

# %%
Q5.empty()
# Out:
# False

# %%
Q5.full()
# Out:
# False

# %%
Q5.put(300)
Q5.put(400)
Q5.put(500)

# %%
Q5.full()
# Out:
# True

# %%
Q5 = Queue(maxsize=5)

# %%
v1 = input("Enter element ")
if not Q5.full():
    Q5.put(v1)
    print("One Element added in Q5")
else:
    print("Your queue is full")
# Out:
# Enter element  666
# Your queue is full

# %%
print(Q5.queue)
# Out:
# deque(['111', '222', '333', '444', '555'])

# %%
#LifoQueue

# %%
from queue import LifoQueue

# %%
LifoQ1 = LifoQueue()

# %%
LifoQ1.put(100)

# %%
LifoQ1.put(200)

# %%
LifoQ1.put(300)

# %%
LifoQ1.get()
# Out:
# 300

# %%
from queue import PriorityQueue

# %%
PQ1 = PriorityQueue()

# %%
PQ1.put((4,'java'))

# %%
PQ1.put((2,'javascript'))

# %%
PQ1.put((3,'react'))

# %%
PQ1.put((1,'python'))

# %%
PQ1.queue
# Out:
# [(1, 'python'), (2, 'javascript'), (3, 'react'), (4, 'java')]

# %%
PQ1.get()
# Out:
# (1, 'python')

# %%
PQ1.get()
# Out:
# (2, 'javascript')
