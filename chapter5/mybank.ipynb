# %%
#banking application

# %%
class Account:
    bankName = 'PNB'
    __bankbal = 0
    def __init__(self,aadhaar,name,accno,custbal=5000):
        self.aadhaar = aadhaar
        self.name = name
        self.accno = accno
        self.custbal = custbal
        print("Your Account Created")
    def deposit(self,accno,amount):
        if accno > 0:
            self.custbal += amount
            print("Amount Deposited {} in your acccount current balance is {} ".format(amount,self.custbal+amount))
    def withdraw(self,accno):
        pass
    def transfer(self,accno1,accno2):
        pass
    def showBankbalance(self):
        pass
    def showCustbalance(self,accno):
        pass

# %%
ramuAccount = Account(567876,'ramu',10001)
# Out:
# Your Account Created

# %%
ramuAccount.custbal
# Out:
# 5000

# %%
ramuAccount.deposit(567876,4000)
# Out:
# Amount Deposited 4000 in your acccount current balance is 13000
