# %%
#lambda function
#a function that doesn't have name

# %%
def add(a,b):
    return a+b

# %%
add(10,20)
# Out:
# 30

# %%
def mult(a,b):return a*b

# %%
mult(2,3)
# Out:
# 6

# %%
lambda a,b:a+b
# Out:
# <function __main__.<lambda>(a, b)>

# %%
add2 = lambda a,b:a+b

# %%
add2(100,200)
# Out:
# 300

# %%
square = lambda n:n*n

# %%
square(5)
# Out:
# 25

# %%
lambda name:"Good Morning "+name
# Out:
# <function __main__.<lambda>(name)>

# %%
(lambda name:"Good Morning "+name)("Ravi")
# Out:
# 'Good Morning Ravi'

# %%
(lambda n:n*n)(5)
# Out:
# 25

# %%
for i in [1,2,3,4,5]:
    print((lambda i:i*3)(i))
# Out:
# 3
# 6
# 9
# 12
# 15
