# %%
#zip is python inbuilt class
#It combines multiple iterable objects like list,tuple,set,...
#reading data element wise as pairs

# %%
type(zip)
# Out:
# type

# %%
courses = ['python','java','react','css','next','node','springboot']

# %%
cids = [1001,1002,1003,1004,1005,1006,1007]

# %%
for course in courses:
    print(course)
# Out:
# python
# java
# react
# css
# next
# node
# springboot

# %%
for cid in cids:
    print(cid)
# Out:
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007

# %% [raw]
# 1001 'python'

# %%
for cid,cname in cids,courses:
    print(cid,cname)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 for cid,cname in cids,courses:
#       2     print(cid,cname)
#
# ValueError: too many values to unpack (expected 2)

# %%
for i in cids,courses:
    print(i)
# Out:
# [1001, 1002, 1003, 1004, 1005, 1006, 1007]
# ['python', 'java', 'react', 'css', 'next', 'node', 'springboot']

# %%
for cid in cids:
    for cname in courses:
        print(cid,cname)
# Out:
# 1001 python
# 1001 java
# 1001 react
# 1001 css
# 1001 next
# 1001 node
# 1001 springboot
# 1002 python
# 1002 java
# 1002 react
# 1002 css
# 1002 next
# 1002 node
# 1002 springboot
# 1003 python
# 1003 java
# 1003 react
# 1003 css
# 1003 next
# 1003 node
# 1003 springboot
# 1004 python
# 1004 java
# 1004 react
# 1004 css
# 1004 next
# 1004 node
# 1004 springboot
# 1005 python
# 1005 java
# 1005 react
# 1005 css
# 1005 next
# 1005 node
# 1005 springboot
# 1006 python
# 1006 java
# 1006 react
# 1006 css
# 1006 next
# 1006 node
# 1006 springboot
# 1007 python
# 1007 java
# 1007 react
# 1007 css
# 1007 next
# 1007 node
# 1007 springboot

# %%
print(*courses)
# Out:
# python java react css next node springboot

# %%
print(*cids)
# Out:
# 1001 1002 1003 1004 1005 1006 1007

# %%
for cid,cname in *cids,*courses:
    print(cid,cname)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 for cid,cname in *cids,*courses:
#       2     print(cid,cname)
#
# TypeError: cannot unpack non-iterable int object

# %%
*cids
# Out:
#   Cell In[12], line 1
#     *cids
#     ^
# SyntaxError: can't use starred expression here

# %%
print(*cids)
# Out:
# 1001 1002 1003 1004 1005 1006 1007

# %%
for cid,cname in [*cids,*courses]:
    print(cid,cname)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 for cid,cname in [*cids,*courses]:
#       2     print(cid,cname)
#
# TypeError: cannot unpack non-iterable int object

# %%
type(zip)
# Out:
# type

# %%
for cid,cname in zip(cids,courses):
    print(cid,cname)
# Out:
# 1001 python
# 1002 java
# 1003 react
# 1004 css
# 1005 next
# 1006 node
# 1007 springboot

# %%
fees = [12000,15000,12500,6000,8000,4500,6500]

# %%
for cid,cname,fee in zip(cids,courses,fees):
    print(cid,cname,fee)
# Out:
# 1001 python 12000
# 1002 java 15000
# 1003 react 12500
# 1004 css 6000
# 1005 next 8000
# 1006 node 4500
# 1007 springboot 6500

# %%
courseInfo = zip(cids,courses,fees)

# %%
pprint
# Out:
# Pretty printing has been turned OFF

# %%
dir(courseInfo)
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__']

# %%
for i in courseInfo:
    print(i)
# Out:
# (1001, 'python', 12000)
# (1002, 'java', 15000)
# (1003, 'react', 12500)
# (1004, 'css', 6000)
# (1005, 'next', 8000)
# (1006, 'node', 4500)
# (1007, 'springboot', 6500)

# %%
for i in courseInfo:
    print(i)

# %%
courseInfo = zip(cids,courses,fees)

# %%
next(courseInfo)
# Out:
# (1001, 'python', 12000)

# %%
courseInfo.__next__()
# Out:
# (1002, 'java', 15000)

# %%
for i in courseInfo:
    print(i)
# Out:
# (1003, 'react', 12500)
# (1004, 'css', 6000)
# (1005, 'next', 8000)
# (1006, 'node', 4500)
# (1007, 'springboot', 6500)

# %%
courses
# Out:
# ['python', 'java', 'react', 'css', 'next', 'node', 'springboot']

# %%
for cid,cname in enumerate(courses,501):
    print(cid,cname)
# Out:
# 501 python
# 502 java
# 503 react
# 504 css
# 505 next
# 506 node
# 507 springboot

# %%
courseInfo = zip(enumerate(courses,501),fees)

# %%
for i in courseInfo:
    print(i)
# Out:
# ((501, 'python'), 12000)
# ((502, 'java'), 15000)
# ((503, 'react'), 12500)
# ((504, 'css'), 6000)
# ((505, 'next'), 8000)
# ((506, 'node'), 4500)
# ((507, 'springboot'), 6500)

# %%
for i in courseInfo:
    print(i)

# %%
courseInfo = zip(enumerate(courses,501),fees)

# %%
for i,j in courseInfo:
    print(i,j)
# Out:
# (501, 'python') 12000
# (502, 'java') 15000
# (503, 'react') 12500
# (504, 'css') 6000
# (505, 'next') 8000
# (506, 'node') 4500
# (507, 'springboot') 6500

# %%
courseInfo = zip(enumerate(courses,501),fees)

# %%
for i,j in courseInfo:
    print(*i,j)
# Out:
# 501 python 12000
# 502 java 15000
# 503 react 12500
# 504 css 6000
# 505 next 8000
# 506 node 4500
# 507 springboot 6500

# %%
zipobj1 = enumerate(zip(courses,fees),2001)

# %%
next(zipobj1)
# Out:
# (2001, ('python', 12000))

# %%
for i,j in zipobj1:
    print(i,j)
# Out:
# 2002 ('java', 15000)
# 2003 ('react', 12500)
# 2004 ('css', 6000)
# 2005 ('next', 8000)
# 2006 ('node', 4500)
# 2007 ('springboot', 6500)

# %%
zipobj2 = enumerate(zip(courses,fees),2001)

# %%
for i in zipobj2:
    print(*i)
# Out:
# 2001 ('python', 12000)
# 2002 ('java', 15000)
# 2003 ('react', 12500)
# 2004 ('css', 6000)
# 2005 ('next', 8000)
# 2006 ('node', 4500)
# 2007 ('springboot', 6500)

# %%
zipobj2 = enumerate(zip(courses,fees),2001)

# %%
next(zipobj2)
# Out:
# (2001, ('python', 12000))

# %%
for cid,crinfo in zipobj2:
    print(cid,*crinfo)
# Out:
# 2002 java 15000
# 2003 react 12500
# 2004 css 6000
# 2005 next 8000
# 2006 node 4500
# 2007 springboot 6500

# %%
"welcome"
# Out:
# 'welcome'

# %% [raw]
# d1 = {asccivalue:'w',asciivalue:'e',asciivalue:'l'}

# %%
for i in "welcome":
    print(ord(i),i)
# Out:
# 119 w
# 101 e
# 108 l
# 99 c
# 111 o
# 109 m
# 101 e

# %%
d1={}

# %%
for i in "welcome":
    d1[ord(i)]=i

# %%
d1
# Out:
# {119: 'w', 101: 'e', 108: 'l', 99: 'c', 111: 'o', 109: 'm'}

# %%
d2={}

# %%
for i in "welcome":
    d2.setdefault(ord(i),i)

# %%
d2
# Out:
# {119: 'w', 101: 'e', 108: 'l', 99: 'c', 111: 'o', 109: 'm'}

# %%
str1 = "welcome"

# %%
for i,j in enumerate("welcome"):
    print(i,j)
# Out:
# 0 w
# 1 e
# 2 l
# 3 c
# 4 o
# 5 m
# 6 e

# %%
str1 = "welcome"

# %%
str1.index('e')
# Out:
# 1

# %%
for i in str1:
    print(str1.index(i),i)
# Out:
# 0 w
# 1 e
# 2 l
# 3 c
# 4 o
# 5 m
# 1 e
