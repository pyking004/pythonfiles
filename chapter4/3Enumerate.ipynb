# %%
#enumerate
#enumerate is going to generate sequence of numbers for each element from the iterable object

# %%
courses = ['python','java','react','css','next','node','springboot']

# %%
for cr in courses:
    print(cr)
# Out:
# python
# java
# react
# css
# next
# node
# springboot

# %%
courses[0]
# Out:
# 'python'

# %%
courses.index('next')
# Out:
# 4

# %%
for i in courses:
    print(courses.index(i))
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in courses:
    print(courses.index(i),i)
# Out:
# 0 python
# 1 java
# 2 react
# 3 css
# 4 next
# 5 node
# 6 springboot

# %%
courses = ['python','java','react','css','next','node','springboot']

# %%
cid,course = 'python'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cid,course = 'python'
#
# ValueError: too many values to unpack (expected 2)

# %%
for cid,cname in courses:
    print(cid,cname)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 for cid,cname in courses:
#       2     print(cid,cname)
#
# ValueError: too many values to unpack (expected 2)

# %%
#enumerate is class
type(enumerate)
# Out:
# type

# %%
courses = ['python','java','react','css','next','node','springboot']

# %%
for cid,cname in enumerate(courses):
    print(cid,cname)
# Out:
# 0 python
# 1 java
# 2 react
# 3 css
# 4 next
# 5 node
# 6 springboot

# %%
for cid,cname in enumerate(courses,5001):
    print(cid,cname)
# Out:
# 5001 python
# 5002 java
# 5003 react
# 5004 css
# 5005 next
# 5006 node
# 5007 springboot

# %%
for cname,cid in enumerate(courses,101):
    print(cname,cid)
# Out:
# 101 python
# 102 java
# 103 react
# 104 css
# 105 next
# 106 node
# 107 springboot

# %%
for i,j in enumerate(courses,501):
    print(i,j)
# Out:
# 501 python
# 502 java
# 503 react
# 504 css
# 505 next
# 506 node
# 507 springboot

# %%
i,j=(101,'python')

# %%
print(i,j)
# Out:
# 101 python

# %%
i = (101,'python')

# %%
i
# Out:
# (101, 'python')

# %%
for i in enumerate(courses,201):
    print(i)
# Out:
# (201, 'python')
# (202, 'java')
# (203, 'react')
# (204, 'css')
# (205, 'next')
# (206, 'node')
# (207, 'springboot')

# %%
for i in enumerate(courses,201):
    print(i[0])
# Out:
# 201
# 202
# 203
# 204
# 205
# 206
# 207

# %%
for i in enumerate(courses,201):
    print(i[0],i[1])
# Out:
# 201 python
# 202 java
# 203 react
# 204 css
# 205 next
# 206 node
# 207 springboot

# %%
for cid,cname in enumerate(courses,201):
    print(cid,cname)
# Out:
# 201 python
# 202 java
# 203 react
# 204 css
# 205 next
# 206 node
# 207 springboot

# %%
#Enumerate is class 
#we can create  objects with classes

# %%
students = ['ravi','ramu','hari','koti','suri']

# %%
stdinfo = enumerate(students,1001)

# %%
print(stdinfo)

# %%
stdinfo[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 stdinfo[0]
#
# TypeError: 'enumerate' object is not subscriptable

# %%
stdinfo[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 stdinfo[:]
#
# TypeError: 'enumerate' object is not subscriptable

# %%
pprint
# Out:
# Pretty printing has been turned OFF

# %%
dir(stdinfo)
# Out:
# ['__class__', '__class_getitem__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']

# %%
for i in stdinfo:
    print(i)
# Out:
# (1001, 'ravi')
# (1002, 'ramu')
# (1003, 'hari')
# (1004, 'koti')
# (1005, 'suri')

# %%
for i in stdinfo:
    print(i)

# %%
students = ['ravi','ramu','hari','koti','suri']

# %%
stdinfo = enumerate(students,2001)

# %%
next(stdinfo)
# Out:
# (2001, 'ravi')

# %%
next(stdinfo)
# Out:
# (2002, 'ramu')

# %%
stdinfo.__next__()
# Out:
# (2003, 'hari')

# %%
for i in stdinfo:
    print(i)
# Out:
# (2004, 'koti')
# (2005, 'suri')

# %%
enumobj1 = enumerate("welcome",101)

# %%
for i in enumobj1:
    print(i)
# Out:
# (101, 'w')
# (102, 'e')
# (103, 'l')
# (104, 'c')
# (105, 'o')
# (106, 'm')
# (107, 'e')

# %%
enumobj2 = enumerate({1:100,2:200,3:300},101)

# %%
for i in enumobj2:
    print(i)
# Out:
# (101, 1)
# (102, 2)
# (103, 3)

# %%
D1 = {1:100,2:200,3:300}

# %%
enumobj3 = enumerate(D1.values(),101)

# %%
for i in enumobj3:
    print(i)
# Out:
# (101, 100)
# (102, 200)
# (103, 300)

# %%
type(enumerate)
# Out:
# <class 'type'>

# %%
type(enumobj3)
# Out:
# <class 'enumerate'>

# %%
D1 = {1:100,2:200,3:300,4:400}

# %%
enumobj4 = enumerate(D1.items(),101)

# %%
for i in enumobj4:
    print(i)
# Out:
# (101, (1, 100))
# (102, (2, 200))
# (103, (3, 300))
# (104, (4, 400))

# %%
s1 = {10,20,30,40,50,10,30,60}

# %%
enumobj5 = enumerate(s1,4001)

# %%
for i in enumobj5:
    print(i)
# Out:
# (4001, 50)
# (4002, 20)
# (4003, 40)
# (4004, 10)
# (4005, 60)
# (4006, 30)
